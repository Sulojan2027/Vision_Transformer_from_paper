# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, Flatten, GlobalAveragePooling2D
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras.applications import ResNet50V2

import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score

# %%
# Load cifar10 dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
x_train = tf.image.resize(x_train, (64, 64))
x_test = tf.image.resize(x_test, (64, 64))
# Out:
# I0000 00:00:1760805192.111752      37 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1760805192.112462      37 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
# Preprocess the data
x_train = tf.keras.applications.resnet.preprocess_input(x_train)
x_test = tf.keras.applications.resnet.preprocess_input(x_test)

# %%
# Data augnentation
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomZoom(0.1),
    tf.keras.layers.RandomRotation(0.1),
])

# %%
# Load the ResNet50V2 model without the top layer
res_model = ResNet50V2(weights='imagenet', include_top=False, input_shape=(64, 64, 3))
res_model.trainable = True
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Add custom top layers

inputs = tf.keras.Input(shape=(64,64,3))
x = data_augmentation(inputs)

x = res_model(x, training=False)
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(10, activation='softmax')(x)

# Final model
model = tf.keras.Model(inputs=inputs, outputs=predictions)

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
    )

lr = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.5,
    patience=3,
    min_lr=1e-5,
    verbose=1
    )

es = EarlyStopping(
    monitor='val_accuracy',
    patience=10,
    verbose=1,
    restore_best_weights=True,
)

# %%
history = model.fit(
    x_train, y_train,
    epochs=30,
    batch_size=64,
    validation_data=(x_test, y_test),
    callbacks=[es, lr]
)
# Out:
# Epoch 1/30
# I0000 00:00:1760805664.135337      98 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 150s 128ms/step - accuracy: 0.4113 - loss: 1.7145 - val_accuracy: 0.2061 - val_loss: 3.2915 - learning_rate: 0.0010
# Epoch 2/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 121ms/step - accuracy: 0.5433 - loss: 1.3243 - val_accuracy: 0.6620 - val_loss: 1.0181 - learning_rate: 0.0010
# Epoch 3/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.6422 - loss: 1.0667 - val_accuracy: 0.7343 - val_loss: 0.7955 - learning_rate: 0.0010
# Epoch 4/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 121ms/step - accuracy: 0.6963 - loss: 0.8989 - val_accuracy: 0.7159 - val_loss: 0.9052 - learning_rate: 0.0010
# Epoch 5/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 121ms/step - accuracy: 0.7139 - loss: 0.8501 - val_accuracy: 0.7364 - val_loss: 0.8379 - learning_rate: 0.0010
# Epoch 6/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.7460 - loss: 0.7571 - val_accuracy: 0.7553 - val_loss: 0.7418 - learning_rate: 0.0010
# Epoch 7/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 121ms/step - accuracy: 0.7579 - loss: 0.7279 - val_accuracy: 0.7839 - val_loss: 0.6498 - learning_rate: 0.0010
# Epoch 8/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 121ms/step - accuracy: 0.7781 - loss: 0.6665 - val_accuracy: 0.7883 - val_loss: 0.6338 - learning_rate: 0.0010
# Epoch 9/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.7923 - loss: 0.6182 - val_accuracy: 0.7663 - val_loss: 0.7185 - learning_rate: 0.0010
# Epoch 10/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.7977 - loss: 0.5975 - val_accuracy: 0.7893 - val_loss: 0.6331 - learning_rate: 0.0010
# Epoch 11/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.8086 - loss: 0.5711 - val_accuracy: 0.7761 - val_loss: 0.7037 - learning_rate: 0.0010
# Epoch 12/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.8168 - loss: 0.5417 - val_accuracy: 0.8111 - val_loss: 0.5895 - learning_rate: 0.0010
# Epoch 13/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.8260 - loss: 0.5143 - val_accuracy: 0.7966 - val_loss: 0.6252 - learning_rate: 0.0010
# Epoch 14/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 121ms/step - accuracy: 0.8335 - loss: 0.4905 - val_accuracy: 0.8322 - val_loss: 0.5102 - learning_rate: 0.0010
# Epoch 15/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.8429 - loss: 0.4637 - val_accuracy: 0.8231 - val_loss: 0.5659 - learning_rate: 0.0010
# Epoch 16/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.8411 - loss: 0.4794 - val_accuracy: 0.8149 - val_loss: 0.5883 - learning_rate: 0.0010
# Epoch 17/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8500 - loss: 0.4366
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 121ms/step - accuracy: 0.8500 - loss: 0.4366 - val_accuracy: 0.8273 - val_loss: 0.5875 - learning_rate: 0.0010
# Epoch 18/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 121ms/step - accuracy: 0.8786 - loss: 0.3616 - val_accuracy: 0.8606 - val_loss: 0.4324 - learning_rate: 5.0000e-04
# Epoch 19/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.8924 - loss: 0.3162 - val_accuracy: 0.8637 - val_loss: 0.4309 - learning_rate: 5.0000e-04
# Epoch 20/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 121ms/step - accuracy: 0.9025 - loss: 0.2864 - val_accuracy: 0.8662 - val_loss: 0.4214 - learning_rate: 5.0000e-04
# Epoch 21/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.9089 - loss: 0.2721 - val_accuracy: 0.8538 - val_loss: 0.4578 - learning_rate: 5.0000e-04
# Epoch 22/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.9102 - loss: 0.2635 - val_accuracy: 0.8607 - val_loss: 0.4666 - learning_rate: 5.0000e-04
# Epoch 23/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9130 - loss: 0.2556
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.9130 - loss: 0.2556 - val_accuracy: 0.8657 - val_loss: 0.4431 - learning_rate: 5.0000e-04
# Epoch 24/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.9305 - loss: 0.2118 - val_accuracy: 0.8819 - val_loss: 0.3951 - learning_rate: 2.5000e-04
# Epoch 25/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.9357 - loss: 0.1893 - val_accuracy: 0.8681 - val_loss: 0.4454 - learning_rate: 2.5000e-04
# Epoch 26/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.9380 - loss: 0.1867 - val_accuracy: 0.8790 - val_loss: 0.4177 - learning_rate: 2.5000e-04
# Epoch 27/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9433 - loss: 0.1711
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.9433 - loss: 0.1711 - val_accuracy: 0.8706 - val_loss: 0.4384 - learning_rate: 2.5000e-04
# Epoch 28/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.9508 - loss: 0.1493 - val_accuracy: 0.8871 - val_loss: 0.4143 - learning_rate: 1.2500e-04
# Epoch 29/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.9543 - loss: 0.1376 - val_accuracy: 0.8840 - val_loss: 0.4185 - learning_rate: 1.2500e-04
# Epoch 30/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.9557 - loss: 0.1324 - val_accuracy: 0.8818 - val_loss: 0.4460 - learning_rate: 1.2500e-04
# Restoring model weights from the end of the best epoch: 28.

# %%
# Plot training & validation accuracy, loss values
history = model.history.history

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Plot training & validation accuracy values
ax1.plot(history['accuracy'], label='Training Accuracy')
ax1.plot(history['val_accuracy'], label='Validation Accuracy')
ax1.set_title('Model Accuracy')
ax1.set_ylabel('Accuracy')
ax1.set_xlabel('Epoch')
ax1.legend()

# Plot training & validation loss values
ax2.plot(history['loss'], label='Training Loss')
ax2.plot(history['val_loss'], label='Validation Loss')
ax2.set_title('Model Loss')
ax2.set_ylabel('Loss')
ax2.set_xlabel('Epoch')
ax2.legend()

plt.savefig('/kaggle/working/accuracy_loss_plot.png', dpi=300, bbox_inches='tight')
plt.tight_layout()
plt.show()

# %%
# Retrieve best metrics
best_train_acc = max(history['accuracy'])
best_val_acc = max(history['val_accuracy'])
print(f"Best training accuracy is {(best_train_acc * 100):.2f}%")
print(f"Best validation accuracy is {(best_val_acc * 100):.2f}%")
# Out:
# Best training accuracy is 95.51%
# Best validation accuracy is 88.71%
